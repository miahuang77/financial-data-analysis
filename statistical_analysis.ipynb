# %% [markdown]
# ## Statistical Analysis and Correlation

# %%
**Goal**  
 Dive into return distributions, test statistical assumptions, and relationships between stocks

**Stocks**  
AAPL,MSFT, NVDA, META, GOOGL, SPY

**Key questions**  
- 1. Are stock returns normally distributed?
- 2. How correlated are these stocks, and does correlation change over time?
- 3. Are the returns of high-performing stocks statistically significant?
# Out:
#   Cell In[16], line 1
#     **Goal**
#     ^
# SyntaxError: invalid syntax
